# %%
from pathlib import Path

# %%
current_path = Path.cwd()
start_dir = current_path/"example_files"
all_files = set(["_".join(fastq.stem.split("_")[0:2]) for fastq in start_dir.glob("*.fastq.gz")])
unique_sample_ct = len(all_files)

all_files
# Out:
# {'KEH-Rep1-7KO-HEK293T-Cyto-BS_S6', 'KEH-Rep1-7KO-HEK293T-Cyto-NBS_S5'}
